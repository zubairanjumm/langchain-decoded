# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("gpt-4.1")
model

# %%
response = model.invoke("hello How are you?")
response.content

# %% [markdown]
# Google gemini model integeration

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model = init_chat_model("google_genai:gemini-3.6-flash")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# [{'type': 'text',
#   'text': 'Parrots “talk” (mimic human speech) due to a combination of **unique physical anatomy, high intelligence, and a deep social need to fit in.** \n\nHere is a breakdown of why and how they do it:\n\n---\n\n### 1. Social Bonding and "Flock" Culture\nIn the wild, parrots are intensely social animals that live in flocks. To survive, they must communicate constantly with their group. \n* **Flock Dialects:** Wild parrots use distinct vocalizations to identify their family members and flock. If a parrot moves to a new flock, it learns the new flock’s "dialect" to fit in.\n* **Humans as the Flock:** When a parrot lives in a human home, **you become its flock**. Because parrots cannot naturally speak "human," they mimic the sounds you make—words, laughter, whistles, even ringtones—to bond with you and feel like a member of the group.\n\n### 2. Physical Anatomy (How They Do It)\nParrots don\'t have vocal cords like humans do. Instead, they produce sounds using a specialized vocal organ called a **syrinx**, located at the base of their windpipe (trachea).\n* By manipulating the muscles around the syrinx and controlling the air flowing through it, they can produce complex sounds.\n* Parrots also use their **thick, muscular tongues** and beak shapes to manipulate the sound, allowing them to produce consonants like *p, b, t,* and *m* without having lips.\n\n### 3. Unique Brain Structure\nParrots have very complex brains. Research shows that the parrot brain contains specific regions dedicated to vocal learning, known as "song centers." \n* What makes parrots unique compared to other vocal-learning birds (like songbirds) is that they have an extra outer layer around these brain centers—called the **"shell" domain**. \n* This shell domain helps parrots process sounds, control their vocal muscles, and imitate complex sounds, including human speech.\n\n### 4. Attention and Reaction\nParrots are dramatic and love attention. Human speech is usually accompanied by enthusiasm, eye contact, and emotion. \n* If a parrot says a word (like "Hello!" or a swear word) and gets a big reaction—like laughter, gasps, or a treat—it learns that making that sound gets them attention. \n* They will repeat the sound over and over to trigger that fun reaction again.\n\n---\n\n### Do Parrots Actually Understand What They Are Saying?\nMost of the time, parrots are using **associative learning** rather than true language comprehension. \n* For example, a parrot might say "Good morning!" when you open their cage because they have associated that phrase with you opening the cage, not because they understand the concept of "morning."\n* However, some highly intelligent species, like the **African Grey**, have shown remarkable cognitive abilities. The famous African Grey named *Alex* (studied by Dr. Irene Pepperberg) demonstrated that he understood concepts like color, shape, size, and numbers, using words accurately to identify objects rather than just blindly repeating them.\n\n### Summary\nParrots talk because **their brains and bodies are built for vocal imitation, and they use human words to connect with their human "flock."**',
#   'extras': {'signature': '...'}}]

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI


model = ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Parrots don’t talk to communicate the way humans do—they don’t understand the full grammatical meaning of human language. Instead, they talk because of a combination of **evolutionary biology, high intelligence, and social survival instincts**. \n\nHere is a breakdown of why parrots talk:\n\n### 1. They are "Vocal Learners"\nMost animals are born knowing the sounds of their species automatically. However, humans, songbirds, hummingbirds, and parrots are **vocal learners**. This means they have to *learn* how to make sounds by listening to others and practicing. In the wild, baby parrots learn the calls of their flock so they can fit in.\n\n### 2. The Flock Mentality\nParrots are intensely social, flock-dwelling animals. In the wild, a parrot needs to sound like its flock to survive. If a parrot sounds different, it might be rejected or targeted by predators. When a parrot lives in a human home, **humans become its flock**. To bond with and be accepted by their "human flock," parrots mimic human sounds. \n\n### 3. High Intelligence and Boredom\nParrots have the cognitive and emotional intelligence of a 4-to-6-year-old human child. They have huge brains relative to their body size. In captivity, talking is often a way to cope with boredom. If a parrot figures out that saying "Hello!" makes a human appear, give it attention, or bring it food, it has learned a very useful survival trick.\n\n### 4. Attention and Reinforcement\nParrots quickly learn cause and effect. \n* If you yell "Uh-oh!" when something drops, and the parrot hears you, it connects the sound to the event. \n* If the parrot mimics the sound and you laugh, look at it, or give it a treat, you have just **rewarded** the behavior. The parrot learns: *"When I make this human noise, I get attention."*\n\n### 5. Physical Anatomy\nWhile other birds (like crows or ravens) are smart enough to mimic speech, parrots have a unique physical tool for it: **the syrinx** (a bird\'s vocal organ) combined with a very flexible, human-like tongue and the ability to control their breath precisely. This allows them to shape sounds in a way that closely mimics human vowels and consonants.\n\n---\n\n### *Do they actually know what they are saying?*\nUsually, they just associate sounds with contexts (e.g., saying "Bye-bye!" when someone grabs their keys). However, famous scientific studies—most notably with an African Grey parrot named **Alex**, trained by Dr. Irene Pepperberg—proved that parrots *can* learn the actual meaning of words. Alex could correctly identify colors, shapes, and numbers, and answer questions about objects, proving that they are capable of true, intentional communication using human words, not just mindless mimicry.', 'extras': {'signature': 'El4KXAERTTIPwhplHxttiqjtKM5FMB8ddIEOx9Dp8otN7uf5tMKz7wnXzDII1BP98gxZTrLwbbboHXaXVHyHWRcxKVGV33bKyJxdZ/bdatf6DgnZrTLIRK9EbRyrGOMJ'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a03f96-4bd1-7622-b54b-7256b7b5a75f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 610, 'total_tokens': 616, 'input_token_details': {'cache_read': 0}})

# %% [markdown]
# Groq model integeration

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:qwen/qwen3-32b")
response = model.invoke("Why do parrots talk?")
response

# %%
import os
from langchain_groq import ChatGroq

model = ChatGroq(model="qwen/qwen3-32b")
response = model.invoke("Why do parrots talk?")
response

# %% [markdown]
# Streaming

# %% [markdown]
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
for chunk in model.stream("Write me a 200 words paragraph on Artificial Intelligence"):
    print(chunk.text, end="|", flush=True)

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="|", flush=True)

# %% [markdown]
# Batch
#
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)

# %%
model.batch(
    ["Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"],
    config={
        'max_concurrency': 5,  # Limit to 5 parallel calls
    }
)
